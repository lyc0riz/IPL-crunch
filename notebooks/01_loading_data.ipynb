# %%
from pathlib import Path
import os
import sys
import json
import pandas as pd

# 1. Load the autoreload extension
# %load_ext autoreload
# 2. Instruct it to reload all modules every time you execute a cell
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Add the folder containing the json files from cricsheet
folder_path = Path('../data/raw/ipl_json')
# Save csv 
output_csv_folder = Path('../data/raw')
output_csv_name = 'ipl-ball-by-ball-dataset.csv'

output_csv_path = os.path.join(output_csv_folder, output_csv_name)

# %%
sys.path.append(os.path.abspath(".."))
from src.json_to_csv import process_cricsheet_data

# %%
# 3. Run the function
df = process_cricsheet_data(folder_path,output_csv_path)

# Display a preview of the dataset without truncating columns
pd.set_option('display.max_columns', None)
if not df.empty:
    display(df.head())
# Out:
# Found 1243 JSON files. Starting extraction...
# Extraction complete! Saved 295732 rows to '../data/raw/ipl-ball-by-ball-dataset.csv'.
#   match_id        date season                  event            venue  \
# 0   392201  2009-04-30   2009  Indian Premier League  SuperSport Park
# 1   392201  2009-04-30   2009  Indian Premier League  SuperSport Park
# 2   392201  2009-04-30   2009  Indian Premier League  SuperSport Park
# 3   392201  2009-04-30   2009  Indian Premier League  SuperSport Park
# 4   392201  2009-04-30   2009  Indian Premier League  SuperSport Park
#
#         city            team1             team2       toss_winner  \
# 0  Centurion  Deccan Chargers  Delhi Daredevils  Delhi Daredevils
# 1  Centurion  Deccan Chargers  Delhi Daredevils  Delhi Daredevils
# 2  Centurion  Deccan Chargers  Delhi Daredevils  Delhi Daredevils
# 3  Centurion  Deccan Chargers  Delhi Daredevils  Delhi Daredevils
# 4  Centurion  Deccan Chargers  Delhi Daredevils  Delhi Daredevils
#
# ...
